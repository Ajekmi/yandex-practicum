# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-и-подготовка-данных" data-toc-modified-id="Загрузка-и-подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка и подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Получаем-информацию-о-данных" data-toc-modified-id="Получаем-информацию-о-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Получаем информацию о данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей-get_profiles" data-toc-modified-id="Функция-для-создания-пользовательских-профилей-get_profiles-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей <code>get_profiles</code></a></span></li><li><span><a href="#Функция-для-расчёта-удержания-get_retention" data-toc-modified-id="Функция-для-расчёта-удержания-get_retention-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для расчёта удержания <code>get_retention</code></a></span></li><li><span><a href="#Функция-для-расчёта-конверсии-get_conversion" data-toc-modified-id="Функция-для-расчёта-конверсии-get_conversion-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для расчёта конверсии <code>get_conversion</code></a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI-get_ltv" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-get_ltv-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI <code>get_ltv</code></a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма-filter_data" data-toc-modified-id="Функция-для-сглаживания-фрейма-filter_data-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для сглаживания фрейма <code>filter_data</code></a></span></li><li><span><a href="#Функция-для-визуализации-удержания-plot_retention" data-toc-modified-id="Функция-для-визуализации-удержания-plot_retention-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция для визуализации удержания <code>plot_retention</code></a></span></li><li><span><a href="#Функция-для-визуализации-конверсии-plot_conversion" data-toc-modified-id="Функция-для-визуализации-конверсии-plot_conversion-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция для визуализации конверсии <code>plot_conversion</code></a></span></li><li><span><a href="#Функция--для-визуализации-LTV-и-ROI-plot_ltv_roi" data-toc-modified-id="Функция--для-визуализации-LTV-и-ROI-plot_ltv_roi-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Функция  для визуализации LTV и ROI <code>plot_ltv_roi</code></a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Построение-профилей-пользователей.-Определение-минимальной-и-максимальной-даты-привлечения-пользователей" data-toc-modified-id="Построение-профилей-пользователей.-Определение-минимальной-и-максимальной-даты-привлечения-пользователей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Построение профилей пользователей. Определение минимальной и максимальной даты привлечения пользователей</a></span></li><li><span><a href="#Исследование-пользователей-из-разных-стран" data-toc-modified-id="Исследование-пользователей-из-разных-стран-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Исследование пользователей из разных стран</a></span></li><li><span><a href="#Исследование-устройств,-которыми-пользуются-клиенты" data-toc-modified-id="Исследование-устройств,-которыми-пользуются-клиенты-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Исследование устройств, которыми пользуются клиенты</a></span></li><li><span><a href="#Исследование-рекламных-каналов" data-toc-modified-id="Исследование-рекламных-каналов-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Исследование рекламных каналов</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Определение-общей-суммы-расходов-на-маркетинг.-Распределение-трат-по-источникам.-Визуализация-изменений-метрик-во-времени." data-toc-modified-id="Определение-общей-суммы-расходов-на-маркетинг.-Распределение-трат-по-источникам.-Визуализация-изменений-метрик-во-времени.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Определение общей суммы расходов на маркетинг. Распределение трат по источникам. Визуализация изменений метрик во времени.</a></span></li><li><span><a href="#Сколько-в-среднем-стоило-привлечение-одного-пользователя-из-каждого-источника.-Рассчет-среднего-CAC-на-одного-пользователя-для-всего-проекта-и-для-каждого-источника-трафика." data-toc-modified-id="Сколько-в-среднем-стоило-привлечение-одного-пользователя-из-каждого-источника.-Рассчет-среднего-CAC-на-одного-пользователя-для-всего-проекта-и-для-каждого-источника-трафика.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Сколько в среднем стоило привлечение одного пользователя из каждого источника. Рассчет среднего CAC на одного пользователя для всего проекта и для каждого источника трафика.</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оцените-окупаемость-рекламы-для-привлечения-пользователей" data-toc-modified-id="Оцените-окупаемость-рекламы-для-привлечения-пользователей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оцените окупаемость рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемости-рекламы" data-toc-modified-id="Анализ-общей-окупаемости-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Проект Procrastinate Pro+
#
# Развлекательное приложение Procrastinate Pro+ несколько прошлых месяцев постоянно несло убытки - в привлечение пользователей была вложена куча денег, а толку никакого. Нужно найти причины этой ситуации.
#
# Данные: лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов.
#
# # Задачи
# Вам предстоит изучить, как люди пользуются продуктом, когда они начинают покупать, сколько денег приносит каждый клиент, когда он окупается и какие факторы отрицательно влияют на привлечение пользователей.
#
# # Описание данных
# Таблица visits_log_short (лог сервера с информацией о посещениях сайта):
#
# * User Id — уникальный идентификатор пользователя
# * Device — категория устройства пользователя
# * Session start — дата и время начала сессии
# * Session End — дата и время окончания сессии
# * Channel — идентификатор рекламного источника, из которого пришел пользователь
# * Region - страна пользователя
#
# Таблица orders_log_short (информация о заказах):
#
# * User Id — уникальный id пользователя, который сделал заказ
# * Event Dt — дата и время покупки
# * Revenue — выручка
#
# Таблица costs_short (информация о затратах на маркетинг):
#
# * Channel — идентификатор рекламного источника
# * Dt — дата
# * Costs — затраты на этот рекламный источник в этот день

# %% [markdown]
# ##  Загрузка и подготовка данных
# Загружаем данные о визитах, заказах и расходах в переменные. Оптимизируем данные для анализа.

# %% [markdown]
# ### Получаем информацию о данных

# %%
# импортируем нужные библиотеки
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %%
# загружаем данные в переменные
visits, orders, costs = (
    pd.read_csv('/datasets/visits_info_short.csv'),  # визиты
    pd.read_csv('/datasets/orders_info_short.csv'),  # заказы
    pd.read_csv('/datasets/costs_info_short.csv'),  # расходы
)

# %%
# функция для вывода информации о данных
def table_info (df):
    print('___________ Датафрейм ____________')
    display(df.head())
    display(df.describe())
    print('')
    print('___________Информация о датафрейме___________')
    print('')
    print(df.info())
    print('')
    print('Количество дубликатов: ' + str(df.duplicated().sum()))
    print('')

# %%
table_info (visits)
# Out:
# ___________ Датафрейм ____________
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#             User Id
# count  3.099010e+05
# mean   4.997664e+11
# std    2.887899e+11
# min    5.993260e+05
# 25%    2.493691e+11
# 50%    4.989906e+11
# 75%    7.495211e+11
# max    9.999996e+11
# ___________Информация о датафрейме___________
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
# ...

# %% [markdown]
# Проверим некоторые качественные столбцы методом value_counts, которые не проверил метод describe.

# %%
visits['Region'].value_counts()
# Out:
# United States    207327
# UK                36419
# France            35396
# Germany           30759
# Name: Region, dtype: int64

# %%
visits['Device'].value_counts()
# Out:
# iPhone     112603
# Android     72590
# PC          62686
# Mac         62022
# Name: Device, dtype: int64

# %%
visits['Channel'].value_counts()
# Out:
# organic               107760
# TipTop                 54794
# FaceBoom               49022
# WahooNetBanner         20465
# LeapBob                17013
# OppleCreativeMedia     16794
# RocketSuperAds         12724
# YRabbit                 9053
# MediaTornado            8878
# AdNonSense              6891
# lambdaMediaAds          6507
# Name: Channel, dtype: int64

# %%
table_info(orders)
# Out:
# ___________ Датафрейм ____________
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#             User Id       Revenue
# count  4.021200e+04  40212.000000
# mean   4.990295e+11      5.370608
# std    2.860937e+11      3.454208
# min    5.993260e+05      4.990000
# 25%    2.511324e+11      4.990000
# 50%    4.982840e+11      4.990000
# 75%    7.433327e+11      4.990000
# max    9.998954e+11     49.990000
# ___________Информация о датафрейме___________
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
# ...

# %%
table_info(costs)
# Out:
# ___________ Датафрейм ____________
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
#              costs
# count  1800.000000
# mean     58.609611
# std     107.740223
# min       0.800000
# 25%       6.495000
# 50%      12.285000
# 75%      33.600000
# max     630.000000
# ___________Информация о датафрейме___________
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
# None
#
# Количество дубликатов: 0

# %%
costs['Channel'].value_counts()
# Out:
# RocketSuperAds        180
# WahooNetBanner        180
# lambdaMediaAds        180
# AdNonSense            180
# YRabbit               180
# MediaTornado          180
# FaceBoom              180
# LeapBob               180
# OppleCreativeMedia    180
# TipTop                180
# Name: Channel, dtype: int64

# %% [markdown]
# Информация, которую удалось получить:
# * В данных нет дубликатов и пропусков.
# * Названия столбцов необходимо привести к правильному виду для удобной работы - использовать нижний регистр и андерскор вместо пробелов.
# * Преобразовать данные о времени в нужный формат.

# %% [markdown]
# ### Предобработка данных

# %%
# перечень названий столбцов таблиц
print(visits.columns)
print(orders.columns)
print(costs.columns)
# Out:
# Index(['User Id', 'Region', 'Device', 'Channel', 'Session Start',
#        'Session End'],
#       dtype='object')
# Index(['User Id', 'Event Dt', 'Revenue'], dtype='object')
# Index(['dt', 'Channel', 'costs'], dtype='object')

# %%
visits.columns = [x.lower().replace(' ', '_') for x in visits.columns]
orders.columns = [x.lower().replace(' ', '_') for x in orders.columns]
costs.columns = [x.lower().replace(' ', '_') for x in costs.columns]

# %%
# проверка результатов - перечень названий столбцов
print(visits.columns)
print(orders.columns)
print(costs.columns)
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')
# Index(['dt', 'channel', 'costs'], dtype='object')

# %%
# преобразование данных о времени
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# ### Вывод
#
# - Названия столбцов приведены к правильному виду - использован нижний регистр и андерскор вместо пробелов.
# - Преобразованы данные о времени в нужный формат.
# - Явных проблем с данными обнаружено не было.

# %% [markdown]
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# Соберём функции для создания профилей, расчёта удержания, конверсии, LTV и ROI: get_profiles(), get_retention(), get_conversion() и get_ltv().

# %% [markdown]
# ### Функция для создания пользовательских профилей `get_profiles`

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs, event_names=[]):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для расчёта удержания `get_retention`

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта конверсии `get_conversion`

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта LTV и ROI `get_ltv`

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# А также функции для визуализации этих метрик — filter_data(), plot_retention(), plot_conversion() и plot_ltv_roi().

# %% [markdown]
# ### Функция для сглаживания фрейма `filter_data`

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации удержания `plot_retention`

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии `plot_conversion`

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция  для визуализации LTV и ROI `plot_ltv_roi`

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Построение профилей пользователей. Определение минимальной и максимальной даты привлечения пользователей

# %%
# получаем профили пользователей
profiles = get_profiles(visits, orders, costs)
profiles
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# Определяем минимальную и максимальную дату привлечения пользователей.Самая поздняя дата будет моментом анализа.

# %%
min_user_date = profiles['dt'].min()

observation_date = profiles['dt'].max()

print(f'Минимальная дата', min_user_date, f'Максимальная дата', observation_date)
# Out:
# Минимальная дата 2019-05-01 Максимальная дата 2019-10-27

# %% [markdown]
# Полученные временные интервалы привлечения пользователей минимальная дата 2019-05-01, максимальная дата 2019-10-27 совпадают с указанным периодом в задании: "... в распоряжении есть лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27."

# %% [markdown]
# ### Исследование пользователей из разных стран

# %% [markdown]
# В этом разделе мы отвечаем на вопросы:
# * Из каких стран приходят посетители?
# * Какие страны дают больше всего платящих пользователей?

# %%
# Сгруппируем данные по регионам, посчитаем число пользователей в каждом регионе, долю каждого региона в общем числе пользователей

pu = profiles.groupby('region').agg({'region':'count'})
pu = pu.rename(columns={'region': 'region_user_count'}).sort_values(by='region_user_count', ascending=False)
pu['ratio_region,%'] = round((pu['region_user_count'] / pu['region_user_count'].sum())* 100,2)

# Посчитаем число платящих пользователей и их долю из общего числа пользователей каждого региона

pu['payer_users_count'] = profiles.query('payer == True').groupby('region').agg({'user_id':'count'})
pu['ratio_payer_users,%'] = round((pu['payer_users_count'] *100 / pu['region_user_count']),2)
pu
# Out:
#                region_user_count  ratio_region,%  payer_users_count  \
# region
# United States             100002           66.66               6902
# UK                         17575           11.72                700
# France                     17450           11.63                663
# Germany                    14981            9.99                616
#
#                ratio_payer_users,%
# region
# United States                 6.90
# UK                            3.98
# France                        3.80
# Germany                       4.11

# %%
sns.countplot(x= 'region', data = profiles, hue='payer').set_title('Распределение платящих/неплатящих (True/False) пользователей по регионам')
plt.show()

# %% [markdown]
# Пользователи приложения являются жители: United States (66,66%), UK(11,72%), France(11,63%), Germany(9,99%).
#
# Из пользователей в США **доля платящих пользователей** больше (6.90%), чем в других странах, в которых эта доля распределилась похожим образом - около 4%.

# %% [markdown]
# ### Исследование устройств, которыми пользуются клиенты

# %% [markdown]
# В этом разделе мы отвечаем на вопросы:
# * Какими устройствами пользуются клиенты?
# * С каких устройств чаще всего заходят платящие пользователи?

# %%
# Сгруппируем данные по устройствам, посчитаем число пользователей каждого устройства, долю каждого устройства в общем числе пользователей

device_users = profiles.groupby('device').agg({'device':'count'})
device_users = device_users.rename(columns={'device': 'device_user_count'}).sort_values(by='device_user_count', ascending=False)
device_users['ratio_device,%'] = round((device_users['device_user_count'] / device_users['device_user_count'].sum())* 100,2)

# Посчитаем число платящих пользователей и их долю из общего числа пользователей каждого устройства

device_users['payer_users_count'] = profiles.query('payer == True').groupby('device').agg({'user_id':'count'})
device_users['ratio_payer_users,%'] = round((device_users['payer_users_count'] *100 / device_users['device_user_count']),2)

device_users
# Out:
#          device_user_count  ratio_device,%  payer_users_count  \
# device
# iPhone               54479           36.32               3382
# Android              35032           23.35               2050
# PC                   30455           20.30               1537
# Mac                  30042           20.03               1912
#
#          ratio_payer_users,%
# device
# iPhone                  6.21
# Android                 5.85
# PC                      5.05
# Mac                     6.36

# %%
sns.countplot(x= 'device', data = profiles, hue='payer').set_title('Распределение платящих/неплатящих (True/False) пользователей по устройствам')
plt.show()

# %% [markdown]
# По приведенной таблице и построенному графику можно сделать вывод о том, что пользователи заходят в приложения с устройств: iPhone (36.32%), Android (23.35%), PC(20.30%), Mac(20.03%).
#
# Чаще всего платящие пользователи являются владельцами Mac (6.36%), также высокая доля платящих у владельцев iPhone (6.21%).

# %% [markdown]
# ### Исследование рекламных каналов

# %% [markdown]
# В этом разделе мы отвечаем на вопросы:
# * По каким рекламным каналам шло привлечение пользователей?
# * Какие каналы приносят больше всего платящих пользователей?

# %%
# Сгруппируем данные по каналам, посчитаем число пользователей каждого канала, долю каждого канала в общем числе пользователей

channel_users = profiles.groupby('channel').agg({'channel':'count'})
channel_users = channel_users.rename(columns={'channel': 'channel_user_count'}).sort_values(by='channel_user_count', ascending=False)
channel_users['ratio_device,%'] = round((channel_users['channel_user_count'] / channel_users['channel_user_count'].sum())* 100,2)

# Посчитаем число платящих пользователей и их долю из общего числа пользователей каждого канала

channel_users['payer_users_count'] = profiles.query('payer == True').groupby('channel').agg({'user_id':'count'})
channel_users['ratio_payer_users,%'] = round((channel_users['payer_users_count'] *100 / channel_users['channel_user_count']),2)

channel_users.sort_values(by='ratio_device,%', ascending=False)
# Out:
#                     channel_user_count  ratio_device,%  payer_users_count  \
# channel
# organic                          56439           37.62               1160
# FaceBoom                         29144           19.43               3557
# TipTop                           19561           13.04               1878
# OppleCreativeMedia                8605            5.74                233
# LeapBob                           8553            5.70                262
# WahooNetBanner                    8553            5.70                453
# RocketSuperAds                    4448            2.97                352
# MediaTornado                      4364            2.91                156
# YRabbit                           4312            2.87                165
# AdNonSense                        3880            2.59                440
# lambdaMediaAds                    2149            1.43                225
#
#                     ratio_payer_users,%
# channel
# ...

# %%
ax = sns.countplot(x= 'channel', data = profiles, hue='payer')
sns.set(rc={'figure.figsize':(15,7)})
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set_title('Распределение платящих/неплатящих (True/False) пользователей по рекламным каналам')
plt.show()

# %% [markdown]
# Рекламные каналы по которым шло привлечение пользователей и их доля в процентах от общего числа пользователей:
#
# Рекламный канал | Доля, %
# :---------------|--------
# organic	| 37.62
# FaceBoom |	19.43
# TipTop	| 13.04
# OppleCreativeMedia	| 5.74
# LeapBob	| 5.70
# WahooNetBanner	| 5.70
# RocketSuperAds	| 2.97
# MediaTornado	| 2.91
# YRabbit	| 2.87
# AdNonSense	| 2.59
# lambdaMediaAds	| 1.43
#
# Наибольшая доля пользователей была привлечена по органическому каналу (37.62%), а также через FaceBoom (19.43%), TipTop (13.04%).
#
# Самая высокая доля платящих пользоватлей из всего количества привлеченных по данному каналу у:
# 1. FaceBoom	12.20%,
# 2. AdNonSense 11.34%,
# 3. lambdaMediaAds 10.47%,
# 4. TipTop 9.60%.

# %% [markdown]
# ### Вывод
# * Минимальная дата привлечения пользователей 2019-05-01 Максимальная дата привлечения пользователей 2019-10-27, что совпадает с указанным периодом в задании.
#
#
# * Пользователи приложения являются жители **стран**: United States (66,66%), UK(11,72%), France(11,63%), Germany(9,99%)
#
#     Из пользователей в США доля платящих пользователей больше (6.90%), чем в других странах, в которых эта доля распределилась похожим образом - около 4%.
#
#     Также можно отметить, что в предоставленных данных больше всего пользователей из США (66.66%).
#
#
# * Пользователи заходят в приложения с **устройств**: iPhone (36.32%), Android (23.35%), PC(20.30%), Mac(20.03%).
#
#     Чаще всего платящие пользователи являются владельцами Mac (доля платящих 6.36%), также высокая доля платящих у владельцев iPhone (6.21%).
#
# * Наибольшая доля пользователей была привлечена по **каналам**:
#     1. Органическому каналу (37.62%)
#     2. FaceBoom (19.43%)
#     3. TipTop (13.04%).
#
# * Самая высокая доля платящих пользоватлей из всего количества привлеченных по данному каналу у:
#     1. FaceBoom	12.20%,
#     2. AdNonSense 11.34%,
#     3. lambdaMediaAds 10.47%,
#     4. TipTop 9.60%.

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# ### Определение общей суммы расходов на маркетинг. Распределение трат по источникам. Визуализация изменений метрик во времени.

# %% [markdown]
# Определим **общую сумму расходов** на маркетинг.

# %%
# Сложим отдельно затраты на рекламу из таблицы costs и стоимость привлечения каждого клиента из profiles. Сравним эти суммы.
costs_sum1 = costs['costs'].sum()
costs_sum2 = profiles['acquisition_cost'].sum()

print(costs_sum1, costs_sum2)
# Out:
# 105497.30000000002 105497.29999999999

# %% [markdown]
# Общая сумма расходов на  рекламу составила 105497.3 рублей

# %% [markdown]
# Определим, как траты распределены **по источникам**.

# %%
money_for_channel = (profiles.groupby('channel')
                     .agg({'acquisition_cost': 'sum'})
                     .sort_values(by ='acquisition_cost', ascending=False))
display(money_for_channel)
# Out:
#                     acquisition_cost
# channel
# TipTop                      54751.30
# FaceBoom                    32445.60
# WahooNetBanner               5151.00
# AdNonSense                   3911.25
# OppleCreativeMedia           2151.25
# RocketSuperAds               1833.00
# LeapBob                      1797.60
# lambdaMediaAds               1557.60
# MediaTornado                  954.48
# YRabbit                       944.22
# organic                         0.00

# %%
money_for_channel.plot(y='acquisition_cost', kind = 'bar', ylabel = 'расходы на рекламу', title ='Расходы на каждый источник рекламы')
plt.show()

# %%
# Приблизим предыдущий график
ax= money_for_channel.plot(y='acquisition_cost', kind = 'bar', ylabel = 'расходы на рекламу', title ='Расходы на каждый источник рекламы (фрагмент по оси y=(0,6000))')
ax.set_ylim(0,6000)
plt.show()

# %% [markdown]
# Большая часть расходов на рекламу занимает реклама в TipTop (54751.30) и FaceBoom (32445.60). Затраты на остальные каналы распределены практически равномерно от 944 до 5151 на каждый канал.

# %% [markdown]
# Визуализируем изменения расходов на рекламу **по каждому каналу во времени**.

# %%
costs_pivot = pd.pivot_table(costs, values='costs', index='dt', columns='channel', aggfunc='sum')
costs_pivot
# Out:
# channel     AdNonSense  FaceBoom  LeapBob  MediaTornado  OppleCreativeMedia  \
# dt
# 2019-05-01       40.95     113.3     2.52          6.24                4.25
# 2019-05-02       34.65      78.1     2.94          5.04                4.25
# 2019-05-03       47.25      85.8     2.73          6.96                5.75
# 2019-05-04       51.45     136.4     3.99          9.36                4.25
# 2019-05-05       36.75     122.1     4.62         11.04                5.50
# ...                ...       ...      ...           ...                 ...
# 2019-10-23       15.75     178.2    10.71          5.28               13.25
# 2019-10-24       21.00     222.2    12.81          5.04               12.50
# 2019-10-25       26.25     255.2    14.70          6.24               16.50
# 2019-10-26       21.00     272.8    14.28          6.72               14.25
# 2019-10-27       35.70     233.2    12.81          4.56               17.75
#
# ...

# %%
costs_pivot.plot(ylabel = 'Расходы на рекламу',
                 xlabel= 'Дата', 
                 title ='Расходы на рекламу по каждому каналу с 01-05-2019 по 27-10-2019')
plt.show()

# %%
# Приблизим предыдущий график, чтобы рассмотреть динамику расходов для каналов помимо TipTop и FaceBoom.
ax = costs_pivot.plot(ylabel = 'Расходы на рекламу',
                 xlabel= 'Дата', 
                 title ='Расходы на рекламу по каждому каналу с 01-05-2019 по 27-10-2019 (фрагмент по оси y=(0,60))')
ax.set_ylim(0,60)
plt.legend(bbox_to_anchor=(1.05,1), loc=2)
plt.show()

# %% [markdown]
# Таким образом делаем вывод, что компания вкладывает большую часть рекламного бюджета в каналы TipTop и FaceBoom.
#
# На графике можно увидеть, что пики вложений TipTop и FaceBoom практически повторяют друг друга, но суммы различаются в пользу TipTop. Мы видим, что изначально в первых числах июня и июля были значительные вложения в эти каналы(возможно пробные), далее с августа в эти площадки стабильно вкладывали большую часть бюджта, в конце сентября и начале октября в TipTop были самые крупные вложения свыше 600(незаданная валюта??).
#
# Остальные каналы финансируются равномерно в течение всего периода исседования и суммы затрат не превышают отметку 50(незаданная валюта??).

# %% [markdown]
# ###  Сколько в среднем стоило привлечение одного пользователя из каждого источника. Рассчет среднего CAC на одного пользователя для всего проекта и для каждого источника трафика.

# %% [markdown]
# Рассчитаем **средний CAC на одного пользователя для всего проекта** и для сравнения рассчитаем медиану:

# %%
#исключим пользователей с органическим трафиком
profiles = profiles.query('channel != "organic"')

# %%
print('Среднее значение CAC на одного пользователя {:.3}'.format(profiles['acquisition_cost'].mean()))
print('Медианное значение CAC на одного пользователя {:.3}'.format(profiles['acquisition_cost'].median()))
# Out:
# Среднее значение CAC на одного пользователя 1.13
# Медианное значение CAC на одного пользователя 1.08

# %% [markdown]
# Медиана (1.08) практически равна среднему (1.13), это означает, что данные распределены симметрично.

# %% [markdown]
# Рассчитаем **средний CAC на одного пользователя по каждому каналу привлечения**. Для этого сгруппируем профили пользователей и применим функцию mean() к значениям столбца `acquisition_cost`.

# %%
# Определим CAC для каждого источника трафика.
cac_channel = pd.DataFrame()
cac_channel['acquisition_cost_mean'] = profiles.groupby('channel')['acquisition_cost'].mean()
cac_channel.sort_values(by='acquisition_cost_mean', ascending=False).style.format({'acquisition_cost_mean': '{:.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_39950_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >acquisition_cost_mean</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_39950_level0_row0" class="row_heading level0 row0" >TipTop</th>
#                         <td id="T_39950_row0_col0" class="data row0 col0" >2.80</td>
#             </tr>
#             <tr>
#                         <th id="T_39950_level0_row1" class="row_heading level0 row1" >FaceBoom</th>
#                         <td id="T_39950_row1_col0" class="data row1 col0" >1.11</td>
#             </tr>
#             <tr>
#                         <th id="T_39950_level0_row2" class="row_heading level0 row2" >AdNonSense</th>
#                         <td id="T_39950_row2_col0" class="data row2 col0" >1.01</td>
#             </tr>
# ...

# %%
cac_channel.sort_values(by='acquisition_cost_mean', ascending=False).plot(kind='bar')
plt.ylabel('CAC')
plt.xlabel('Канал привлечения')
plt.title('Распределение среднего САС по каналам привлечения')
plt.show()

# %% [markdown]
# По средней стоимости привлечения одного клиента лидирует TipTop	(2.80), FaceBoom (1.11), AdNonSense	(1.01), заметим, что первые два канала по результатам предыдущих исследований получают большую часть рекламного бюджета. Органический трафик бесплатен.

# %%
# Построим график изменений CAC по каналам привлечения
profiles.pivot_table(index='dt', columns='channel', values='acquisition_cost', aggfunc='mean').plot(grid=True, figsize=(10, 5))
plt.ylabel('CAC')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.legend(bbox_to_anchor=(1, 1),fontsize=11)
plt.show()

# %% [markdown]
# На графике динамики CAC видно, что CAC для канала TipTop повышалась практически в каждом месяце. Для остальных каналов динамика была стабильно и не имела резких скачков.

# %% [markdown]
# ### Вывод
#
# Таким образом делаем вывод, что компания вкладывает большую часть рекламного бюджета в каналы TipTop и FaceBoom.
#
# На графике можно увидеть, что пики вложений TipTop и FaceBoom практически повторяют друг друга, но суммы различаются в пользу TipTop. Мы видим, что изначально в первых числах июня и июля были значительные вложения в эти каналы(возможно пробные), далее с августа в эти площадки стабильно вкладывали большую часть бюджта, в конце сентября и начале октября в TipTop были самые крупные вложения свыше 600(незаданная валюта??).
#
# Остальные каналы финансируются равномерно в течение всего периода исседования и суммы затрат не превышают отметку 50(незаданная валюта??).
#
# Медиана (1.08) практически равна среднему (1.13), это означает, что данные распределены симметрично.
#
# По средней стоимости привлечения одного клиента лидирует TipTop (2.80), FaceBoom (1.11), AdNonSense (1.01), заметим, что первые два канала по результатам предыдущих исследований получают большую часть рекламного бюджета. Органический трафик бесплатен.
#
# На графике динамики CAC видно, что CAC для канала TipTop повышалась практически в каждом месяце. Для остальных каналов динамика была стабильно и не имела резких скачков.

# %% [markdown]
# ## Оцените окупаемость рекламы для привлечения пользователей
#
# С помощью LTV и ROI:
# - Проанализируйте общую окупаемость рекламы;
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам;
# - Проанализируйте окупаемость рекламы с разбивкой по странам;
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам.
#
# Опишите проблемы, которые вы обнаружили. Ответьте на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучите конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Опишите возможные причины обнаруженных проблем и сформируйте рекомендации для рекламного отдела. При решении этого шага считайте, что вы смотрите данные 1-го ноября 2019 года и что в вашей организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.

# %% [markdown]
# ### Анализ общей окупаемости рекламы

# %% [markdown]
# Установим момент и горизонт анализа данных. Исключим из анализа органических пользователей, так как на их привлечение мы не тратим деньги.

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа 
#исключим пользователей с органическим трафиком
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# Оценим общую окупаемость рекламы. Рассчитаем и визуализируем LTV и ROI, вызвав функции get_ltv() и plot_ltv_roi().

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# * Общий показатель LTV в исследуемом периоде растет, так и должно быть, расчеты произведены корректно.
# * Затраты на привлечение одного клиента **CAC к концу исследуемого периода возрастают и имеют схожую динамику с изменением CAC канала Tip Top**, т.е. можно сделать вывод, что этот канал сильно влияет на общий показатель CAC.
# * **Реклама не окупается т.к ROI в конце периода — чуть выше 80%**.
# * Динамика ROI даёт нам понять, что в начале исследования показатель LTV превышал CAC и окупаемость была больше единицы т.е. 100%, но потом начал стремительно падать. **Показатель ROI снизился от 140% до 60%**.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %%
# смотрим окупаемость с разбивкой по устройствам

dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# У владельцев Android:
# * линия LTV на одном уровне с Mac и iPhone, выше PC;
# * показатель CAC у Android ниже, чем у пользователей Mac и iPhone;
# * ROI ниже уровня окупаемости, но если посмотреть на показатель ROI  в динамике, то видно, что в начале исследования он был выше, чем у остальных устройств и уже в июне спустился ниже порогового значения и не превышал его.
#
# У владельцев Mac и iPhone показатели близки, поэтому рассматриваем их совместно:
# * LTV выше PC, значит пользователи Mac и iPhone приносят больше выручки;
# * самые высокие показатели СAC, которые имеют тенденцию к росту;
# * очень низкий ROI, тенденция к снижению;
# * в динамике ROI у владельцев Mac и iPhone видны разные стартовые значения в мае - у iPhone реклама окупалась, а у владельцев Mac она окупалась лишь в июне.
#
# У владельцев PC:
# * LTV ниже, чем у остальных;
# * показатель СAC ниже остальных;
# * высокий ROI и единственный кто окупается, в динамике видно окупающаяся линия пользователей PC после резкого скачка в конце июля, в сентябре уже идет на спад и уже в октбре даже не пересекает уровень окупаемости.

# %%
# смотрим конверсию с разбивкой по устройствам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Самая слабая конверсия у пользователей PC, высокая у Mac и iPhone.

# %%
# смотрим удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удержание показывает сколько пользователей из когорты относительно их изначального числа воспользовались продуктом или услугой, в последующие периоды. Как видно удержание неплатящих пользователей очень низкое и одинаковое на всех устройствах.
# У платящих пользователей PC Retention Rate выше всего.

# %% [markdown]
# Подведем итог по разделу:
#
# - PC - низкий LTV, низкий СAC, высокий ROI (единственный кто окупается), слабая конверсия и высокое удержание.
#
# - Mac и iPhone  - LTV выше PC, высокий СAC, очень низкий ROI (тенденция к снижению), высокая конверсия, удержание меньше остальных. (рассматриваем совместно, потому что значения близки)
#
# - Android - LTV выше PC, средний CAC, низкий ROI (не окупается), средняя конверсия, удержание невысокое.
#
# По приведенным итогам можно сделать вывод, что окупаемость к концу периода снизилась для всех устройств, неплохо держались пользователи PC, но на графике динамики видно, что даже они не окупаются после сентября, очень плохая ситуация у Mac и iPhone, стоимость их привлечения сравнительно высокая и постоянно растет, а их выручка нет, стоит обратить на это внимание.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %%
# смотрим окупаемость с разбивкой по странам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Судя по графику, самый высокий LTV — у пользователей из США. Затем идут Великобритания и Германия. Пользователи из Франции приносят магазину меньше всего выручки.
#
# На графике CAC явно высокие показатели затрат на рекламу в США, которые растут в течение всего периода, остальные страны с середины июня имеют стабильный CAC, ниже первоначального.
#
# Реклама у пользователей из США не окупается, в динамике показатель ROI от первоначального значения выше 1 стал падать и не превышал более этот значимый уровень. В остальных странах ROI превышал пороговое значение, это означает, что инвестиции окупались.

# %%
# смотрим конверсию с разбивкой по странам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Высокая конверсия у США, низкая у остальных стран. В динамике в конце мая у всех стран наблюдался взлет конверсии.

# %%
# смотрим удержание с разбивкой по странам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Самое слабое удержание у США. Остальные страны примерно на одном уровне.

# %% [markdown]
# Определим каналы привлечения, используемые в United States

# %%
profiles.query('region == "United States"').value_counts('channel')
# Out:
# channel
# FaceBoom          29144
# TipTop            19561
# RocketSuperAds     4448
# MediaTornado       4364
# YRabbit            4312
# dtype: int64

# %% [markdown]
# Построим графики окупаемости с разбивкой по источникам привлечения для United States

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('region == "United States"'), orders, observation_date, horizon_days, dimensions=['channel']
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Каналы TipTop и FaceBoom для пользователей США не окупаются.

# %% [markdown]
# Построим графики удержания с разбивкой по рекламным каналам для United States

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles.query('region == "United States"'), visits, observation_date, horizon_days, dimensions=['channel']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# По графикам удержания видно, что среди пользователей в США канал FaceBoom имеет самое низкое удержание по сравнению с остальными каналами в этом регионе.

# %% [markdown]
# Итог по разделу:
#
# * США самый высокий LTV, высокий CAC (тенденция к росту), ROI низкий (не окупается),высокая конверсия, слабое удержание.
# Каналы TipTop и FaceBoom для пользователей США не окупаются. Среди пользователей в США канал FaceBoom имеет самое низкое удержание, что влияет на общий показатель для США.
#
# * Франция, Германия, Великобритания имеют LTV немного меньше США, стабильно низкий CAC, ROI превышал пороговое значение,реклама окупается. Конверсия ниже, чем у США, удержание наоборот выше.
#
# Рекоммендации:
#
# На всех графиках наблюдается отделение линии США от остальных стран, это единственная страна, где стоимость привлечения клиентов растет и в которой реклама не окупается, хотя изначально в мае по графику динамики видно, что она окупалась, видимо произошло что-то, что повлияло на окупаемость в худшую сторону, стоит обратить на это внимание.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %%
# смотрим окупаемость с разбивкой по источникам привлечения

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Среди всех источников трафика на первом графике выделяется lambdaMediaAds - у этого источника самая высокая выручка с одного клиента, следом за ним по выручке идет TipTop.Показатель LTV FaceBoom, AdNonSense, WahooNetBanner в начале исследуемого периода был высок, но практически не изменился за всё время.
#
# На графике CAC стоимость привлечения стабильна и одинакова для всех каналов, кроме TipTop, его стоимость росла с каждым месяцем.
#
# На графиках ROI большинство каналов привлечения окупаются, можно выделить YRabbit, который имел очень высокую окупаемость в июле, lambdaMediaAds, MediaTornado - стабильно хорошие показатели и др.
#
# И есть несколько убыточных каналов: AdNonSense, FaceBoom, TipTop.

# %%
# смотрим конверсию с разбивкой по рекламным каналам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Хорошая конверсия у FaceBoom, AdNonSense, lambdaMediaAds.
# Низкая у OppleCreativeMedia, LeapBob, MediaTornado, YRabbit

# %%
# смотрим удержание с разбивкой по рекламным каналам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# На графиках сразу видно низкое удержание FaceBoom и AdNonSense

# %% [markdown]
# Итоги по разделу:
# Среди всех источников трафика на первом графике выделяется lambdaMediaAds - у этого источника самая высокая выручка с одного клиента, следом за ним по выручке идет TipTop.Показатель LTV FaceBoom, AdNonSense, WahooNetBanner в начале исследуемого периода был высок, но практически не изменился за всё время.
#
# На графике CAC стоимость привлечения стабильна и одинакова для всех каналов, кроме TipTop, его стоимость росла с каждым месяцем.
#
# На графиках ROI большинство каналов привлечения окупаются, можно выделить YRabbit, который имел очень высокую окупаемость в июле, lambdaMediaAds, MediaTornado - стабильно хорошие показатели и др. И есть несколько убыточных каналов: AdNonSense, FaceBoom, TipTop.
#
# Хорошая конверсия у FaceBoom, AdNonSense, lambdaMediaAds. Низкая у OppleCreativeMedia, LeapBob, MediaTornado, YRabbit
# На графиках сразу видно низкое удержание FaceBoom и AdNonSense.
#
# Рекоммендации:
#
# 1. Однозначно можно дать рекоммендацию присмотреться к lambdaMediaAds, так как с этого канала самая высокая выручка с одного клиента, хорошая окупаемость и высокая конверсия.
# 2. Пересмотреть инвестирования в TipTop, так как стоимость инвестирования в него растет, а показатель окупаемости ROI низкий, т.е. эта площадка не окупается.
# 3. Возможно нужно приглядеться к показателям FaceBoom и AdNonSense. Эти каналы не окупаются (AdNonSense с переменным успехом), у них достаточно высокие затраты на привлечение одного клиента и они имеют низкий коэффициент удержания клиентов.

# %% [markdown]
# ### Вывод
#
# _Окупается ли реклама в целом?_
#
# **Реклама не окупается т.к ROI в конце периода — чуть выше 80%**. Динамика ROI даёт нам понять, что в начале исследования показатель LTV превышал CAC и окупаемость была больше единицы т.е. 100%, но потом начал стремительно падать. **Показатель ROI снизился от 140% до 60%**.
#
# _Какие устройства, страны и каналы могут снижать окупаемость рекламы?_
#
# Окупаемость к концу периода **снизилась для всех устройств**, неплохо держались пользователи PC, но на графике динамики видно, что даже они не окупаются после сентября, очень плохая ситуация у Mac и iPhone, стоимость их привлечения сравнительно высокая и постоянно растет, а их выручка нет.
#
# Наблюдается отделение линии **США** от остальных стран, это единственная страна, где стоимость привлечения клиентов растет и в которой реклама не окупается, хотя изначально в мае по графику динамики видно, что она окупалась. Конкретно для США не окупаются каналы TipTop и FaceBoom, а канал FaceBoom имеет самое низкое удержание, что влияет на общий показатель для этого региона.
#
# На графиках ROI большинство каналов привлечения окупаются, можно выделить YRabbit, который имел очень высокую окупаемость в июле, lambdaMediaAds, MediaTornado - стабильно хорошие показатели и др. И есть несколько убыточных каналов: **AdNonSense, FaceBoom, TipTop.**
#
# _Чем могут быть вызваны проблемы окупаемости?_
#
# Скорее всего были выбраны неправильные каналы привлечения, пользователи Android, PC и iPhone окупались в начале исследования в мае, а пользователи Mac окупались в июне, возможно произошли какие-то перемены в приложении и этим вызваны такие перемены. Пользователи из США плохо удерживаются из-за удержания канала FaceBoom, они не окупаются в особенности каналы каналы TipTop и FaceBoom, а заполучить их всё дороже, так как это основная часть пользователей приложения, они очень сильно влияют на общую окупаемость.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Пользователи приложения являются жители **стран**:
# 1. United States (66,66%)
# 2. UK(11,72%)
# 3. France(11,63%)
# 4. Germany(9,99%)
#
# Из пользователей в США доля платящих пользователей больше (6.90%), чем в других странах, в которых эта доля распределилась похожим образом - около 4%.
#
# Пользователи заходят в приложения с **устройств**:
# 1. iPhone (36.32%)
# 2. Android (23.35%)
# 3. PC(20.30%)
# 4. Mac(20.03%)
#
# Чаще всего платящие пользователи являются владельцами Mac (доля платящих 6.36%), также высокая доля платящих у владельцев iPhone (6.21%).
#
# Наибольшая доля пользователей была привлечена по **каналам**:
# 1. Органическому (37.62%)
# 2. FaceBoom (19.43%)
# 3. TipTop (13.04%).
#
# Самая высокая доля платящих пользоватлей из всего количества привлеченных по данному каналу у:
# 1. FaceBoom	12.20%,
# 2. AdNonSense 11.34%,
# 3. lambdaMediaAds 10.47%,
# 4. TipTop 9.60%.
#
# **Реклама не окупается** т.к ROI в конце периода — чуть выше 80%. Динамика ROI даёт нам понять, что в начале исследования показатель LTV превышал CAC и окупаемость была больше единицы т.е. 100%, но потом начал стремительно падать. Показатель ROI снизился от 140% до 60%.
#
# Окупаемость к концу исследуемого периода снизилась для всех _устройств_, неплохо держались пользователи PC, но на графике динамики видно, что даже они не окупаются после сентября, очень плохая ситуация у Mac и iPhone, стоимость их привлечения сравнительно высокая и постоянно растет, а их выручка нет.
#
# США - это единственная _страна_, где стоимость привлечения клиентов растет и в которой реклама не окупается, хотя изначально в мае по графику динамики видно, что она окупалась. В этом регионе не окупаются каналы TipTop и FaceBoom. Пользователи из США плохо удерживаются из-за низкого удержания канала FaceBoom, и так как это основная часть пользователей приложения, они очень сильно влияют на общую окупаемость. В этом регионе высокий показатель конверсии, что говорит нам о том, что клиенты лучше переходят из неплатящих в платящих. Высокий показатель LTV, говорит нам, что эти клиенты более платежеспособные для нашего приложения. Нужно исправить момент с удержанием клиентов и по возможности найти дешевые и эффективные каналы привлечения, так как из этого региона у нашего приложения больше всего пользователей.
#
# По _каналам привлечения_, можно выделить YRabbit, который имел очень высокую окупаемость в июле, lambdaMediaAds, MediaTornado - стабильно хорошие показатели и др. И есть несколько убыточных каналов: AdNonSense, FaceBoom, TipTop.
# 1. Однозначно можно дать рекоммендацию присмотреться к lambdaMediaAds, так как с этого канала самая высокая выручка с одного клиента, хорошая окупаемость и высокая конверсия.
# 2. Пересмотреть инвестирования в TipTop, так как стоимость инвестирования в него растет, а показатель окупаемости ROI низкий, т.е. эта площадка не окупается.
# 3. Также нужно пересмотреть направления инвестиций в FaceBoom и AdNonSense. Эти каналы не окупаются (AdNonSense с переменным успехом), у них достаточно высокие затраты на привлечение одного клиента и они имеют низкий коэффициент удержания клиентов.
